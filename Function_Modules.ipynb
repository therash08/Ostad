# %% [markdown]
# ## Table of Contents
# - Introduction to Functions
# - Parameters & Arguments
# - Return values
# - Keyword Arguments
# - Variable Scope
# - Built-in Modules

# %% [markdown]
# ## Introduction to Functions
#
# **A function is a reusable block of code that performs a specific task.**
#
# 🧠 Think of it like a machine:
#
# - You give it some input
#
# - It does something
#
# - It gives back output
#
#
# 💡 so, Function is kind of like a machine (let’s say a coffee machine) which can take input (e.g., coffee beans, milk, sugar, etc.), then process it (grind the beans, heat the water, mix everything together), and finally give some output (a cup of coffee).

# %%
# Scenario: An e-commerce system needs to calculate final price of products

# -------------------------------
# ❌ BAD PRACTICE: Repeating code
# -------------------------------

# Case 1
price = 1000       # oven
tax_rate = 0.15   # 25%
total_price = price + (price * tax_rate)   # logic / calcultion -> final price
print("Final Price:", total_price)


# Case 2 (same logic repeated)
price = 2000     # tv
tax_rate = 0.15
total_price = price + (price * tax_rate) # logic / calcultion -> final price
print("Final Price:", total_price)


# Case 3 (same logic repeated again)
price = 500     # t-shirt
tax_rate = 0.15
total_price = price + (price * tax_rate)  # logic / calcultion -> final price
print("Final Price:", total_price)



# ❗ Problem:
# - Code duplication
# - Hard to maintain
# - If tax rate changes, you must update everywhere
# Out:
# Final Price: 1150.0
# Final Price: 2300.0
# Final Price: 575.0

# %%
# ============================================================
# ✅ GOOD PRACTICE: Turn repeated logic into a FUNCTION
# ============================================================

def calculte_final_price(price):
    tax_rate = 0.25
    total_price = price + (price * tax_rate)  # logic / calcultion -> final price
    print("Final Price:", total_price)

# %%
# -------------------------------
# Using the function (Reusable!)
# -------------------------------

calculte_final_price(3000)   # shirt
calculte_final_price(2490)   # panjabi
calculte_final_price(3400)   # pant
calculte_final_price(220)    # t-shirt
# Out:
# Final Price: 3750.0
# Final Price: 3112.5
# Final Price: 4250.0
# Final Price: 275.0

# %%
# ============================================================
# ✅ Why this is better (Function Usability)
# ============================================================

# 1️⃣ Reusability:
#    Same logic used multiple times without rewriting code

# 2️⃣ Maintainability:
#    Change tax rate in ONE place only

# 3️⃣ Readability:
#    calculate_final_price() clearly explains WHAT the code does

# 4️⃣ Scalability:
#    This function can now be used in:
#    - Web backends
#    - Mobile apps
#    - ML pipelines # FUNCTION
#    - Payment systems #

# 👉 This is the shift from "writing scripts" to "building software"

# %%
name = "Saihan"
print(f"Hello {name}")
print(f"How are you {name}")
# Out:
# Hello Saihan
# How are you Saihan

# %%
name = "Shovon"
print(f"Hello {name}")
print(f"How are you {name}")
# Out:
# Hello Shovon
# How are you Shovon

# %%
# function definition - creating the machine
def greet(name):
    print(f"Hello {name}")
    print(f"How are you {name}?")

# %% [markdown]
# - In Python, functions are defined using the `def` keyword.
#
# - After def, we write the function name, followed by parentheses `()` and a colon `:`.
#
# - The code inside the function must be `indented (spaced)`.
#
# - Running a function is called `function calling`.
#
# - Basic Syntax
# ```python
# def function_name():
#     codeblock
# ```
#
# - Defining a Function (But Not Calling It)
# ```python
# # This does not do anything yet
# def greet():
#     print("Hello World")  # This won't run because it's only defined
# ```
# - Calling the function
# ```python
# greet()  # prints "Hello World" , cause the funtion is called here
# ```
# - Defining a function ≠ Running a function
#     - `def greet():` → Creates the function
#     - `greet()` → Runs the function

# %%
# function calling - using the machine
greet("Shovon")
# Out:
# Hello Shovon
# How are you Shovon?

# %%
greet("Sadia")
# Out:
# Hello Sadia
# How are you Sadia?

# %% [markdown]
# ## Parameters & Arguments
#
# `Parameters` are variables defined inside the function parentheses.
# They act as placeholders so the function can work with different values.
#
# `Arguments` are the actual values you pass into the function when calling it.
#
# #### 📌 Why This Matters
# Parameters allow your functions to work with **dynamic data**, making them flexible and reusable.
#
# #### Example
#
# ```python
# def greet_name(name):
#     print(f"Hello {name}")
# ```
#
# Here:
# - `name` → Parameter
# - It is defined when we create the function.
#
# #### Calling (Running) the Function
# ```python
# greet_name("Sayem")
# greet_name("Shovon")
# ```
#
# Here:
# - `Sayem` and `Shovon` → Arguments
# - These are the real values passed into the function.
#
#
# **Default parameter:** A default parameter is a parameter that already has a value assigned in the function definition.
#
# If you don’t provide a value when calling the function, Python uses the default.
#
# ```python
# # Example
# def greet_name(name="Guest"):
#     print(f"Hello {name}")
#
# greet_name("Sayem")   # Output: Hello Sayem
# greet_name()          # Output: Hello Guest
# ```
#
# - "Sayem" → overrides the default
#
# - No argument → uses "Guest" as the default

# %%
# function defintion -> creating the machine
# coffee machine -> slot -> milk powder, coffe powder , sugar

def greet(name):  # -> slot/placeholder -> parameter
    print(f"Hello {name}")
    print(f"How are you {name}?")

# %%
# fucntion calling -> using the machine

greet("Sayem") # actual value passed -> argument
# Out:
# Hello Sayem
# How are you Sayem?

# %%
greet('Shovon')
# Out:
# Hello Shovon
# How are you Shovon?

# %%
greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_357/2890983093.py in <cell line: 0>()
# ----> 1 greet()
#
# TypeError: greet() missing 1 required positional argument: 'name'

# %%
def greet(name="Guest"):  # -> default parameter
    print(f"Hello {name}")
    print(f"How are you {name}?")

# %%
greet()
# Out:
# Hello Guest
# How are you Guest?

# %%
greet("Hasan")
# Out:
# Hello Hasan
# How are you Hasan?

# %%
## Machine leaning Use Case

## person -> age, sallary, family_member_count

## data - normalize - 0 - 1 -> fed into ml model

# %%
age = 80
max_age = 100
age/max_age
# Out:
# 0.8

# %%
salary = 60000
max_salary = 100000
salary/ max_salary
# Out:
# 0.6

# %%
def normalize_data(value, max_value):
    # Normalize value between 0 and 1
    normalized = value / max_value
    print(f"Original: {value} | Normalized: {normalized}")

# Passing arguments into the function
normalize_data(80, 100)

normalize_data(60000, 100000)
# Out:
# Original: 80 | Normalized: 0.8
# Original: 60000 | Normalized: 0.6

# %% [markdown]
# ## Return Values
#
# A function can send data back to the main program using return.
#
# 📢 Important
# - `print()` only displays output
# - `return` sends data for further processing

# %%
# ============================================================
# EXAMPLE: Understanding `print` vs `return`
# Real Use Case: Student Result Processing System
# ============================================================


# -------------------------------
# ❌ Using print (NOT reusable)
# -------------------------------

def calculate_grade_print(marks):
    grade = "A" if marks >= 80 else "B" # logic
    print("Grade:", grade)

# Output is shown, but cannot be reused
result = calculate_grade_print(85)
print("Stored result:", result)


# ❗ Problem:
# - The grade is displayed
# - But it cannot be stored, compared, or sent elsewhere
# Out:
# Grade: A
# Stored result: None

# %%
# ============================================================
# ✅ Using return (Reusable & Powerful)
# ============================================================

def calculate_grade_return(marks):
    grade = "A" if marks >= 80 else "B" # logic
    return grade


# -------------------------------
# Using returned value
# -------------------------------

student_grade = calculate_grade_return(85)
print("Grade:", student_grade)
# Out:
# Grade: A

# %%
# ============================================================
# ✅ Why `return` is important
# ============================================================

# 1️⃣ The returned value can be stored in variables
# 2️⃣ It can be used in conditions
# 3️⃣ It can be passed to another function
# 4️⃣ Essential for real-world software logic


# Example: Decision making using returned value
if student_grade == "A":
    print("Eligible for scholarship")
else:
    print("Keep improving!")


# 👉 Rule of Thumb:
# Use `print()` for debugging or displaying info
# Use `return` for building real applications
# Out:
# Eligible for scholarship

# %% [markdown]
# ## Keyword Arguments
#
# 🏷️ Keyword Arguments
#
# Explicitly specify parameter names — order does not matter.
#
# These features make functions easier to use and harder to misuse.

# %%
def calculate_final_price(price, tax_rate):
    total = price + price*tax_rate
    print(f"Total: {total}")
    return total

# %%
# postion matters -> positional arguments
calculate_final_price(0.15, 3000)   # wrong argument order-> 0.15 (tax_rate) should be the 2nd argument
calculate_final_price(3000, 0.15)   # right argument order
# Out:
# Total: 450.15
# Total: 3450.0
# 3450.0

# %%
# postion doesn't matter  -> keyword arguments
calculate_final_price(price=3000, tax_rate=0.15)
calculate_final_price(tax_rate=0.15, price=3000)
# Out:
# Total: 3450.0
# Total: 3450.0
# 3450.0

# %%
def send_email(user_email, subject="Welcome!", body="Thanks for joining."):
    print(f"To: {user_email}")
    print(f"Subject: {subject}")
    print(f"Content: {body}")

# %%
send_email("support@ostad.com")  # user_email must be passed - no default value for user_email
# Out:
# To: support@ostad.com
# Subject: Welcome!
# Content: Thanks for joining.

# %%
send_email("support@ostad.com", "Eid Offer 2026")
# Out:
# To: support@ostad.com
# Subject: Eid Offer 2026
# Content: Thanks for joining.

# %%
send_email("support@ostad.com", "Eid Offer 2026", "Get 37% discounts on all courses")
# Out:
# To: support@ostad.com
# Subject: Eid Offer 2026
# Content: Get 37% discounts on all courses

# %%
# Using keyword arguments
send_email(
    body="Your OTP is 1234",
    user_email="admin@site.com",
    subject="Security Alert"
)
# Out:
# To: admin@site.com
# Subject: Security Alert
# Content: Your OTP is 1234

# %%
# Using positionnal arguments - order matters
send_email(
    "Your OTP is 1234",
    "admin@site.com",
    "Security Alert"
)
# wrong order -> program may crash
# Out:
# To: Your OTP is 1234
# Subject: admin@site.com
# Content: Security Alert

# %%
# Using positionnal arguments - order matters
send_email(
    "admin@site.com",
    "Security Alert",
    "Your OTP is 1234"
)
# right order
# Out:
# To: admin@site.com
# Subject: Security Alert
# Content: Your OTP is 1234

# %% [markdown]
# ## Variable Scope
#
# `Scope` means where a variable can be accessed in your code.
#
#
# 1. Local Scope: A variable created inside a function
# ```python
# def greet():
#     message = "Hello"
#     print(message)
#
# greet()    ##  works
# print(message) ## Error
# ```
# - variable `message` works inside the function
# - It does NOT exist outside
# - Local variables live only inside the function
#
#
# 2. Global Scope: A variable created outside all functions.
#
# ```python
# name = "Shovon"
#
# def show():
#     print(f"Hello {name}")
#
# show()   ## works
# print(name)  ## also works
# ```
#
# - Variable `name` is accessible both inside and outside of the function
# - Global variables can be read inside functions.
#
# #### 🏠 Think of Scope Like Rooms in a House
#
# - **Local Scope**: Variables inside a function (private room)
# - **Global Scope**: Variables outside functions (shared space)
#
# Understanding scope prevents **unexpected bugs**.

# %%
def greet():
    user = "Sayem"   # local scope
    print(f"Hello, welcome back {user}")
greet()
print(user) # here variable `user` cannot be accessed outside of the function
# Out:
# Hello, welcome back Sayem
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_357/1305939058.py in <cell line: 0>()
#       3     print(f"Hello, welcome back {user}")
#       4 greet()
# ----> 5 print(user) # here variable `user` cannot be accessed outside of the function
#
# NameError: name 'user' is not defined

# %%
user_name = "Jahid"  # global scope
def greet_v2():
    print(f"Hello, welcome back {user_name}")

greet_v2()
print(user_name) # here variable `user_name` can be accessed outside of the function
# Out:
# Hello, welcome back Jahid
# Jahid

# %%
app_name = "AI-Manager"  # Global variable


def register_user():
    print(f"Thanks for signing up in {app_name}")

register_user()

def login_user():
    username = "Shovon"  # Local variable
    print(f"Logging into {app_name} as {username}")

login_user()
# Out:
# Thanks for signing up in AI-Manager
# Logging into AI-Manager as Shovon

# %%
# Uncommenting the line below will cause an error
print(username) # variable `username` is in local scope of the function `login_user`
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_357/4268306901.py in <cell line: 0>()
#       1 # Uncommenting the line below will cause an error
# ----> 2 print(username) # variable `username` is in local scope of the function `login_user`
#
# NameError: name 'username' is not defined

# %% [markdown]
# ## Error Handling with Try & Except
# Errors happen. Good software handles them gracefully instead of crashing.
#
# 🎯 Why Use Try-Except?
# - Protect your program from invalid user input
# - Improve user experience
# - Essential for production-ready code

# %%
def divide(a, b):
    if b == 0:
        return "Division not possible"
    return a/b

# %%
print(divide(10, 2))
# Out:
# 5.0

# %%
print(divide(10, 0))
# Out:
# Division not possible

# %%
print(divide(10, "a"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_357/240332376.py in <cell line: 0>()
# ----> 1 print(divide(10, "a"))
#
# /tmp/ipykernel_357/2240016500.py in divide(a, b)
#       2     if b == 0:
#       3         return "Division not possible"
# ----> 4     return a/b
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def safe_divide(a, b):
    try:
        if b==0 :
            return "Not possible"
        result = a / b
        return result
    except Exception as e:
        return e

print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide(10, "a"))
# Out:
# 5.0
# Not possible
# unsupported operand type(s) for /: 'int' and 'str'

# %%
def safe_divide(a, b):
    try:
        result = a / b
        return result
    # custom user friendly messages for each errors (2 except blocks)
    except ZeroDivisionError:
        return "Error: You cannot divide by zero!"
    except TypeError:
        return "Error: Please provide numeric values only."

print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide(10, "a"))
# Out:
# 5.0
# Error: You cannot divide by zero!
# Error: Please provide numeric values only.

# %%
def safe_divide(a, b):
    try:
        return a / b
    # a single custom error message for all errors
    except Exception:
        return "Error: Something went wrong. Please check your input."

print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide(10, "a"))
# Out:
# 5.0
# Error: Something went wrong. Please check your input.
# Error: Something went wrong. Please check your input.

# %% [markdown]
# ## Built-in Modules
#
# Python follows a `Batteries Included` philosophy.
#
# You get some powerful tools without installing anything extra
#
# - random
# - datetime

# %%
import random

cards = ["king", "queen", "Jack"]

choice = random.choice(cards)

choice
# Out:
# 'king'

# %%
## Number guessing game

computer = random.randint(1, 10)

while True:
    guess = int(input("Try to guess the number: "))

    if guess == computer:
        print("hurray")
        break
# Out:
# Try to guess the number: 3
# Try to guess the number: 7
# Try to guess the number: 6
# Try to guess the number: 4
# Try to guess the number: 5
# Try to guess the number: 2
# Try to guess the number: 1
# Try to guess the number: 8
# hurray

# %%
print(computer)
# Out:
# 8

# %%
## datetime

from datetime import datetime, date

# %%
today = datetime.today()

# %%
today
# Out:
# datetime.datetime(2026, 3, 11, 20, 6, 10, 324123)

# %%
today.strftime("Date: %Y-%m-%d  Time: %H:%M:%S  Day: %A")
# Out:
# 'Date: 2026-03-11  Time: 20:06:10  Day: Wednesday'
