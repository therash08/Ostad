# %% [markdown]
# # Python Fundamentals: From Data to Logic

# %%
# Problem -> logic->Python (Framework)

# %%
# chatbot -> user frontend query -> backend(logic) -> response

# # Lead Collection (Backend)
# chatbot -> Form (Name, Email , Age , Chatbot use Reason) ->Data collect -> Database

# Name -> blank ? && Number , Special character         (validation -> String Manupulation)
# Email ->  @gmail.com


# Machine Learning Dataset (Object(Str)) -> String Manupulation

# %% [markdown]
# ## 1. Cleaning User Input

# %%
raw_name = "     tahmiD rahMan.    "

# %%
type(raw_name)
# Out:
# str

# %%
raw_name.upper()
# Out:
# '     TAHMID RAHMAN.    '

# %%
# strip()
# title()
# replace()

# %%
# MovieDataset Imdb

#Movie Rating | Review (Description) | Genre | Sentiment

# %%
raw_name = "     tahmiD rahMan.    "
clean_name = raw_name.strip().title()
print(f"Welcome,{clean_name}")
# Out:
# Welcome,Tahmid Rahman.

# %%
raw_name = "     tahmiD rahMan.    "
clean_name = raw_name.strip().title() #
print(f"Welcome,{clean_name}!")
# Out:
# Welcome,Tahmid Rahman.!

# %%
# password : Aa@ (min 8 chara) (logic validate)

# %%
input("")

# %% [markdown]
# ### 🧹 Cleaning User Input (String Processing)
#
# - **`strip()`** removes unnecessary spaces from the beginning and end of the text.
# - **`title()`** converts the name into proper case (first letter capitalized).
# - **`f-string`** is used to insert the cleaned name into a message.
#
# ✅ This is commonly used in **signup forms** and **user profiles** to keep data clean and professional.

# %%
unique -> username

username -> all letter must be in lower case ,  length of the user >= 5 , username is taken or not

# %% [markdown]
# ## 2. Username Validation

# %%
True | False

# %%
len("tahmid")>=5
# Out:
# True

# %%
username="tahmid37"
username.islower()
# Out:
# True

# %%
username="ostad_ai"
username.islower() # True | False


True
# Out:
# True

# %%
print(" " not in username)
# Out:
# True

# %%
len(username) >= 5
# Out:
# True

# %%
username=["tahmid12","ostad33"]
new_user="tahmid37"

print(new_user not in username) # in -> membership check

# in ->membership -> if present then true otherwise false
# not in -> if not present then true otherwise false
# Out:
# True

# %%
T and  T and  T -> T

F      T      T -> F

# %%
if ........ -> True
  .............
elif .............. True
    .............
elif ..............

else

# %%
# T and F and T -> F

# %%
# conditional statement

# username -> lower case | min 5 word | username not taken


username=["tahmid12","ostad33"]
new_user="tahmioddd"


# true and true and true  ()
if new_user.islower() and len(new_user) >= 5 and new_user not in username  :
   print(f"{new_user} is valid")
else:
   print("Invalid username")
# Out:
# tahmioddd is valid

# %%
username = "ostad"
if username.islower() and  " " not in username and len(username) >= 5:  # small letter
    print("Username accepted ✅")
else:
    print("Invalid username ❌")
# Out:
# Username accepted ✅

# %% [markdown]
# ### ✅ Username Validation Logic
#
# - **`islower()`** ensures all characters are lowercase.
# - **`" " not in username`** prevents spaces in the username.
# - **`len(username) >= 5`** enforces a minimum length.
# - **`and`** ensures all conditions must be true.
#
# 🔐 Used in **login systems** to maintain clean and secure usernames.

# %% [markdown]
# ## 3. Log File Parsing

# %%
# Backend log (usercreate , userdelete , userupdate , system , database ) -> log file (text file ) -> analytics (summary)

"Success,2026-02-25,SERVER-01,CPU_OVERLOAD"
"Error"

# %%
log = "ERROR,2025-01-15,SERVER-03,CPU_OVERLOAD"
types,date,task,reason=log.split(",")
print(f"{types} {date} {task} {reason}")
# Out:
# ERROR 2025-01-15 SERVER-03 CPU_OVERLOAD

# %%
log = "ERROR,2025-01-15,SERVER-03,CPU_OVERLOAD"
a,b,c,d=log.split(",")
print(d)
# Out:
# CPU_OVERLOAD

# %%
10

# %%
log = "ERROR|2025-01-15|SERVER-03|CPU_OVERLOAD"
level, date, server, issue = log.split("|")
print(f"Issue detected on {server} at {date}: {issue}")
# Out:
# Issue detected on SERVER-03 at 2025-01-15: CPU_OVERLOAD

# %% [markdown]
# ### 📄 Log File Parsing
#
# - **`split("|")`** breaks the log string into separate parts.
# - **Multiple assignment** stores each part into meaningful variables.
# - **f-string** formats the log data into a readable message.
#
# 🛠️ Commonly used in **server monitoring** and **error analysis systems**.

# %% [markdown]
# ### 1️⃣ Extracting Country Code from Phone Number (Slicing)

# %%
phone = "+8801712345678"
country_code=phone[0:4]
real_number=phone[4:]
print(country_code,real_number)
# Out:
# +880 1712345678

# %%
phone = "+8801712345678"
country_code = phone[:4] # First slice
number = phone[4:]  # 2nd slice
print(country_code, number)
# Out:
# +880 1712345678

# %% [markdown]
# #### Slicing ([:]) is used to extract fixed parts of structured data.

# %% [markdown]
# ###2️⃣ Masking Sensitive Data (Slicing + Concatenation)

# %%
nid = "1998123456789"
masked_nid = nid[:4] + "*****" + nid[-3:]
print(masked_nid)
# Out:
# 1998*****789

# %% [markdown]
#     Protects sensitive information while displaying partial data.
#     🔐 Used in banking and government portals.

# %% [markdown]
# 3️⃣ Reversing a String (Password Check / Palindrome)

# %%
string = "Ostad"
string[: : -1]
# Out:
# 'datsO'

# %%
string = "level"
reverse_string = string[::-1]

if string == reverse_string:
    print("Palindrome detected")
else:
    print("Not a palindrome")
# Out:
# Palindrome detected

# %%
string = "level"
reversed_string = string[::-1]
print(reversed_string)
# Out:
# level

# %%
word = "level"
reversed_word = word[::-1]
reversed_word
# Out:
# 'level'

# %%
word = "level"
reversed_word = word[::-1]

if word == reversed_word:
    print("Palindrome detected")
else :
   print("Not a Palindrome")
# Out:
# Palindrome detected

# %%
# string[:: -1]
# Out:
# 'level'

# %% [markdown]
# [::-1] reverses a string quickly.
# 🧠 Used in data validation and interview logic tests.

# %% [markdown]
# 4️⃣ Replacing Unwanted Characters (Cleaning Data)

# %%
product_code = "Tahmid##Rahman"
clean_code = product_code.replace("#", " ")
print(clean_code)
# Out:
# Tahmid  Rahman

# %% [markdown]
# replace() removes or updates unwanted symbols.
# 🏷️ Used in inventory and product systems.

# %% [markdown]
# if condition1 and conditition2 not condition3

# %%
username = "ostad"
if username.islower() and  " " not in username and len(username) >= 5:  # small letter
    print("Username accepted ✅")
else:
    print("Invalid username ❌")
# Out:
# Username accepted ✅

# %% [markdown]
# ## 4. While Loop: ATM PIN System

# %%
# correct_pin = "1234"
# attempts = 0 # 3 times attempt , Maximum thereshold =3
# 0 1 2 3
# while attempts < 3 :

# %%
correct_pin = "1234"
attempts = 0 # 3 times attempt , Maximum thereshold =3
while attempts < 3:   #0 < 3 # (True) # 2       3
    pin = input("Enter PIN: ")
    if pin == correct_pin:
        print("Access Granted")
        break #
    attempts += 1
else:
    print("Card Blocked")

print("New logic start from here")
# Out:
# Enter PIN: 1234
# Access Granted
# New logic start from here

# %%
print("Hello \nWorld")
# Out:
# Hello
# World

# %% [markdown]
# ## 5. Mini Project: Smart User Validator

# %%
raw_data = "   USER:2025-Ostad-77 | STATUS:active   "
clean_data = raw_data.strip().upper()
sections= clean_data.split("|")
user_id = sections[0].split(":")[1]
status = sections[1].split(":")[1]
user_id[:4]
# Out:
# '2025'

# %%
#
name ="Ostad"
temp=name[::-2]
temp
# Out:
# 'dtO'

# %%
raw_data = "   USER:2025-Ostad-77 | STATUS:active   "
clean_data = raw_data.strip().upper()
sections = clean_data.split("|")
user_id = sections[0].split(":")[1]
status = sections[1].split(":")[1]
year = user_id[:4]

if status == "ACTIVE" and year == "2025":
    print(f"User {user_id} authorized")
else:
    print("Access denied")
# Out:
# User 2025-OSTAD-77  authorized

# %%
sections
user_id= sections[0].split(":")[1]
user_id.strip()
# Out:
# '2025-OSTAD-77'
