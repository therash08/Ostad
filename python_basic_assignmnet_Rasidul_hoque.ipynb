# %% [markdown]
# python basic assignment
#
# Rasidul Hoque Chowdhury
#
# ai_engineer bootcamp batch 6

# %% [markdown]
# prb_1

# %%
print('Welcome to Python Programming!')
print('I am learning the basics.')
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# prb_2

# %%
name = 'Rash'
age = 23

print(f"My Name is {name} and I am {age} years old.")
# Out:
# My Name is Rash and I am 23 years old.

# %% [markdown]
# prb-3

# %%
name = input("Enter name: ")
language = input("Enter your favorite programming language: ")

print(f"Hello {name}, your favorite language is {language}.")
# Out:
# Enter name: rash
# Enter your favorite programming language: python
# Hello rash, your favorite language is python.

# %% [markdown]
# prb-4

# %%
num1 = input("enter 1st number")
num2 = input("enter 2nd number")

num1 = int(num1)
num2 = int(num2)

sum = num1 + num2
sum
# Out:
# enter 1st number10
# enter 2nd number20
# 30

# %% [markdown]
# prb - 5

# %%
num1 = input("Enter 1st number: ")
num2 = input("Enter 2nd number: ")

num1 = int(num1)
num2 = int(num2)

add = num1 + num2
sub = num1 - num2
mul = num1 * num2

print(f"Addition: {add}")
print(f"Subtraction: {sub}")
print(f"Multiplication: {mul}")
# Out:
# Enter 1st number: 20
# Enter 2nd number: 10
# Addition: 30
# Subtraction: 10
# Multiplication: 200
